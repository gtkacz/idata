# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
from random import choice
from numpy import mean, array, arange

rcParams['figure.figsize'] = 10, 5

# %%
earnings=pd.read_csv('./bases/earnings_female.csv')
employed=pd.read_csv('./bases/employed_gender.csv')
jobs=pd.read_csv('./bases/jobs_gender.csv')

# %% [markdown]
# # EARNINGS

# %%
labels=[]

for index, row in earnings.iterrows():
    if row['group'] not in labels:
        labels.append(row['group'])

# %%
values=[15,0,0,0,0,0,0]

for k in range(len(values)-1):
    values[k+1]=values[k]+values[0]
    
colors=['b','g','r','c','m','y','orange']

means={}

# %%
j=0

for i in labels:
    df=earnings[earnings.group == i]
    Mean=(mean(array(df.percent)))
    means[i]=Mean
    st=str(round(means.get(i),1))
    label=i+", mean: "+st+'%'
    
    if i=='Total, 16 years and older':
        plt.plot(df.Year, df.percent, label=label, c='k')
        #plt.text(10.2, df.y5.tail(1), 'Mr Orange', horizontalalignment='left', size='small', color='orange')
        
    else:
        s=(values[j])
        c=choice(colors)
        colors.remove(c)


        plt.scatter(df.Year, df.percent, label=label, alpha=0.75, s=s, c=c)
        #plt.text(x=.8, y=list(df.percent)[0], s=st)
    
        j+=1

#fig = plt.gcf()
#plt.grid(True)
plt.legend(bbox_to_anchor=(.95, .47))
plt.xlabel("Ano", fontsize=18)
plt.ylabel("Salário do sexo feminino como porcentagem do salário do sexo masculino (%)", fontsize=10)
plt.show()
#fig.savefig('grafico1.svg', bbox_inches='tight')

# %% [markdown]
# # EMPLOYED

# %%
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        
labels = (employed.year)
plot = {'total_full_time':(employed.total_full_time),
        'total_part_time':(employed.total_part_time),
        'full_time_male':(employed.full_time_male),
        'part_time_male':(employed.part_time_male),
        'full_time_female':(employed.full_time_female),
        'part_time_female':(employed.part_time_female)}

x = arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

for k in plot.keys():
    c=0
    v=[]
    for vs in plot[k]:
        while c<10:
            v.append(vs)
            break
        c+=1
    v.append(round(mean(v),1))
    v=v[:1:-1]
    plot[k]=v

# %%
fig, ax = plt.subplots()
rects=[]
pi=1

for i in list(plot.keys())[:2]:
    v=plot.get(i)
    print(v)
    if pi%2==0:
        rects.append(ax.bar(x - width/2, v, width, label=i))
    else:
        rects.append(ax.bar(x + width/2, v, width, label=i))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Ano')
ax.set_ylabel('Porcentagem de empregados (%)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

for r in rects:
    autolabel(r)

fig.tight_layout()

plt.show()
# Out:
# [84.4, 83.3, 83.3, 83.4, 84.2, 84.4, 84.3, 84.4, 84.8]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1a997ae91331> in <module>
#       9         rects.append(ax.bar(x - width/2, v, width, label=i))
#      10     else:
# ---> 11         rects.append(ax.bar(x + width/2, v, width, label=i))
#      12
#      13 # Add some text for labels, title and custom x-axis tick labels, etc.
#
# ~\Anaconda3\envs\robotica\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\robotica\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2428                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2429
# -> 2430         x, height, width, y, linewidth = np.broadcast_arrays(
#    2431             # Make args iterable too.
#    2432             np.atleast_1d(x), height, width, y, linewidth)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\Anaconda3\envs\robotica\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
#     260     if all(array.shape == shape for array in args):
#
# ~\Anaconda3\envs\robotica\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     187     # use the old-iterator because np.nditer does not handle size 0 arrays
#     188     # consistently
# --> 189     b = np.broadcast(*args[:32])
#     190     # unfortunately, it cannot handle 32 or more arguments directly
#     191     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
